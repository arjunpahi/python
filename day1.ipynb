# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **What Are Strings?**
# In Python a string is a series, or sequence, of characters in order. It is represented by ('').

# %%
print('Hello')
# Out:
# Hello

# %%
print(Hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-85bf5114fa6b> in <module>()
# ----> 1 print(Hello)
#
# NameError: name 'Hello' is not defined

# %% [markdown]
# Method: capitalize()
#
# ```
# # This is formatted as code
# #captialize() >> converts the first character to upper case
# #casefold() >> converts string into lower case
# #center() >> returns a centere string
# ```

# %% [markdown]
# Upper case the first letter in this sentence:

# %%
text = 'hello world, and welcome to the virtual world'

# %%
text.capitalize()
# Out:
# 'Hello world, and welcome to the virtual world'

# %% [markdown]
# What happens when the first character is a number

# %%
tx = "25 is my age."

# %%
#call txt on caitalize function
x = tx.capitalize()

# %%
#print x
x
# Out:
# '25 is my age.'

# %% [markdown]
# Python String format() Method

# %%
"""insert the price inside the placeholder
 the price should be in fixed point, two-decimal format"""
# Out:
# 'insert the price inside the placeholder\n the price should be in fixed point, two-decimal format'

# %% [markdown]
# The format() method formates the specified values()
#
# ---
#
# 1.   The placeholder defines by using curly brackets: {}.
# #syntax
# string.format(value1, value2...)

# %%
txt1 = "My name is {fname}, I'am {age}".format(fname="Raj", age = 30)
txt1 = "My date of {birth} is {date}".format(birth ="birth", date=1992)

# %%
tx2 = "I live in {city}, since {date}".format(city= "KTM", date = "2015")
t2 = "My name is {}, I'm {}".format("RAJ", 19)
t1 = "My name is {fname}, I'm {dob}".format(fname = "Raj", dob = 25)
#Here we used two different approach to print out same sentence.

# %%
t1
# Out:
# "My name is Raj, I'm 25"

# %%
# Allows multiple values to populate the string
name = "Raj"
age = 25
print("{} is {} years old".format(name, age))
# Out:
# Raj is 25 years old

# %%
p = "A Book's price is {price:.2f} dollars!"

# %%
print(p.format(price= 49))
# Out:
# A Book's price is 49.00 dollars!

# %%
#Can specify an index for the substitution
#using number indexes {0}, and {1}, {2}...
fs = "Hello {1} {0}, you got {2}%"
print(fs.format('Ram', 'Hari Sharma', 75))
# Out:
# Hello 75 Hari Sharma, you got Hari Sharma%

# %% [markdown]
# In this case the second string 'Hari Sharma' will be bound the first placeholder; note that
# the parameters are numbered from Zero not one.

# %%
# Can use named substitutions, order is not significant
format_string = "{artist} sang {song} in {year}"
print(___.format(artist='___',
song='___', year=___))

# %%
#In this case the output is:

# %% [markdown]
# #Within this gap you can also indicate an alignment where:
#
# • > Indicates right alignment,
#
# • < Indicates left alignment (the default),
#
# • ^ Indicates centered

# %%
#These follow the colon (':') and come before the size of the gap to use, for example:
print('|{:<25}|'.format('___')) # The default
print('|{:>25}|'.format('___'))
print('|{:^25}|'.format('___'))
# Out:
# |___                      |
# |                       __|
# |           __            |

# %%
#@title syntax str.formating 
#Another formatting option is to indicate that a number should be formatted with separators (such as a comma) to indicate thousands:

# %%
# Can format numbers with comma as thousands separator
#put any number and with decimal in second print
print('{:,}'.format(12345))
print('{:,}'.format(12345.0))
# Out:
# 12,345
# 12,345.0

# %% [markdown]
# >String Formatting in Python using %
# In Python a string of required formatting can be achieved by different methods.
# Some of them are ;
#
# 1.   Using %
# 2.   Using {}
# 2.   Using template

# %%
import numpy as np 
import matplotlib.pyplot as plt

g =9.8 
h_0=1.6
v_0 =14.2
t= 0.5
t = np.linspace(0.5,2.0,50)
v=v_0-g*t
h = h_0 + v_0*t -0.5*g*t**2
plt.xlabel('time')
plt.ylabel('height')
plt.plot(t, h, '-')
t
# Out:
# array([0.5       , 0.53061224, 0.56122449, 0.59183673, 0.62244898,
#        0.65306122, 0.68367347, 0.71428571, 0.74489796, 0.7755102 ,
#        0.80612245, 0.83673469, 0.86734694, 0.89795918, 0.92857143,
#        0.95918367, 0.98979592, 1.02040816, 1.05102041, 1.08163265,
#        1.1122449 , 1.14285714, 1.17346939, 1.20408163, 1.23469388,
#        1.26530612, 1.29591837, 1.32653061, 1.35714286, 1.3877551 ,
#        1.41836735, 1.44897959, 1.47959184, 1.51020408, 1.54081633,
#        1.57142857, 1.60204082, 1.63265306, 1.66326531, 1.69387755,
#        1.7244898 , 1.75510204, 1.78571429, 1.81632653, 1.84693878,
#        1.87755102, 1.90816327, 1.93877551, 1.96938776, 2.        ])

# %%
h
# Out:
# array([ 7.475     ,  7.75510204,  8.02602041,  8.2877551 ,  8.54030612,
#         8.78367347,  9.01785714,  9.24285714,  9.45867347,  9.66530612,
#         9.8627551 , 10.05102041, 10.23010204, 10.4       , 10.56071429,
#        10.7122449 , 10.85459184, 10.9877551 , 11.11173469, 11.22653061,
#        11.33214286, 11.42857143, 11.51581633, 11.59387755, 11.6627551 ,
#        11.72244898, 11.77295918, 11.81428571, 11.84642857, 11.86938776,
#        11.88316327, 11.8877551 , 11.88316327, 11.86938776, 11.84642857,
#        11.81428571, 11.77295918, 11.72244898, 11.6627551 , 11.59387755,
#        11.51581633, 11.42857143, 11.33214286, 11.22653061, 11.11173469,
#        10.9877551 , 10.85459184, 10.7122449 , 10.56071429, 10.4       ])
